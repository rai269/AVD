# %% [markdown]
# <a href="https://colab.research.google.com/github/rai269/AVD/blob/main/Checkpoint_AVD_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **CHECKPOINT 2**

# %% [markdown]
# ## **DATA UNDERSTANDING**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('/content/titles.csv')
df
# Out:
#             id                            title  type  \
# 0      ts21930                  Lupin the Third  SHOW
# 1      ts25177               Mobile Suit Gundam  SHOW
# 2      ts35087               Galaxy Express 999  SHOW
# 3      ts82387                    Lupin the 3rd  SHOW
# 4       ts2846        Chōdenji Machine Voltes V  SHOW
# ...        ...                              ...   ...
# 1076  ts252949         Farewell, My Dear Cramer  SHOW
# 1077  ts267874  I★Chu: Halfway Through the Idol  SHOW
# 1078  ts268254             ABCiee Working Diary  SHOW
# 1079  ts285889       GLOOMY The Naughty Grizzly  SHOW
# 1080  ts255190                          Idolls!  SHOW
#
#                                             description  release_year  \
# 0     Arsene Lupin III is the grandson of the master...          1971
# 1     Mobile Suit Gundam is a televised anime series...          1979
# 2     Galaxy Express 999 is a manga written and draw...          1978
# ...

# %% [markdown]
# **1. Pemeriksaan pada struktur data**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1081 entries, 0 to 1080
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    1081 non-null   object
#  1   title                 1081 non-null   object
#  2   type                  1081 non-null   object
#  3   description           1050 non-null   object
#  4   release_year          1081 non-null   int64
#  5   age_certification     750 non-null    object
#  6   runtime               1081 non-null   int64
#  7   genres                1081 non-null   object
#  8   production_countries  1081 non-null   object
#  9   seasons               1080 non-null   float64
#  10  imdb_id               927 non-null    object
#  11  imdb_score            907 non-null    float64
#  12  imdb_votes            907 non-null    float64
#  13  tmdb_popularity       1068 non-null   float64
#  14  tmdb_score            1006 non-null   float64
# ...

# %% [markdown]
# **2. Banyak Kolom dan Baris**

# %%
print(f"Kolom: {df.shape[0]}")
print(f"Baris: {df.shape[1]}")
# Out:
# Kolom: 1081
# Baris: 15

# %% [markdown]
# **3. Statistik Deskriptif**

# %%
df.describe()
# Out:
#        release_year      runtime      seasons  imdb_score     imdb_votes  \
# count   1081.000000  1081.000000  1080.000000  907.000000     907.000000
# mean    2013.367253    21.548566     1.725926    6.830650    3796.401323
# std        8.339731    11.474517     2.345282    1.012411   19513.703283
# min     1967.000000     0.000000     1.000000    1.400000       5.000000
# 25%     2011.000000    23.000000     1.000000    6.300000      69.500000
# 50%     2016.000000    23.000000     1.000000    6.900000     268.000000
# 75%     2018.000000    24.000000     2.000000    7.500000    1174.500000
# max     2022.000000   208.000000    51.000000    9.100000  325381.000000
#
#        tmdb_popularity   tmdb_score
# count      1068.000000  1006.000000
# mean         21.686957     7.149702
# std          50.583960     1.440071
# min           0.000120     1.000000
# 25%           4.479750     6.400000
# 50%          10.501500     7.400000
# 75%          22.821250     8.200000
# ...

# %% [markdown]
# **4. Analisis Korelasi**

# %%
print("\nMenghitung korelasi antar kolom numerik dengan df.corr():")
print(df.corr(numeric_only=True))
# Out:
# Menghitung korelasi antar kolom numerik dengan df.corr():
#                  release_year   runtime   seasons  imdb_score  imdb_votes  \
# release_year         1.000000 -0.108813 -0.193233   -0.240148   -0.093838
# runtime             -0.108813  1.000000  0.013502    0.203725    0.050061
# seasons             -0.193233  0.013502  1.000000    0.211182    0.231163
# imdb_score          -0.240148  0.203725  0.211182    1.000000    0.296220
# imdb_votes          -0.093838  0.050061  0.231163    0.296220    1.000000
# tmdb_popularity      0.051693  0.056656  0.223112    0.283422    0.331750
# tmdb_score          -0.055748  0.216908  0.113295    0.492096    0.170150
#
#                  tmdb_popularity  tmdb_score
# release_year            0.051693   -0.055748
# runtime                 0.056656    0.216908
# seasons                 0.223112    0.113295
# imdb_score              0.283422    0.492096
# imdb_votes              0.331750    0.170150
# ...

# %% [markdown]
# ## **DATA PREPARATION**

# %% [markdown]
# Sumber data ini adalah [Cruncyroll Animes and Movies](https://www.kaggle.com/datasets/victorsoeiro/crunchyroll-animes-and-movies?select=titles.csv)

# %% [markdown]
# ### **1. Missing Values**

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# id                       0.000000
# title                    0.000000
# type                     0.000000
# description              2.867715
# release_year             0.000000
# age_certification       30.619796
# runtime                  0.000000
# genres                   0.000000
# production_countries     0.000000
# seasons                  0.092507
# imdb_id                 14.246068
# imdb_score              16.096207
# imdb_votes              16.096207
# tmdb_popularity          1.202590
# tmdb_score               6.938020
# dtype: float64

# %% [markdown]
# ada beberapa missing values, yang palinig banyak adalah age certification, dikarenakan banyak anime yang tidak diberikan batasan umur.

# %% [markdown]
# ### **2. Duplikat**

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, title, type, description, release_year, age_certification, runtime, genres, production_countries, seasons, imdb_id, imdb_score, imdb_votes, tmdb_popularity, tmdb_score]
# Index: []

# %% [markdown]
# tidak ada data duplikat

# %% [markdown]
# ### **3. Outliers**

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, '% Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom            % Outliers
# release_year       7.678076
# runtime           23.959297
# seasons            6.567993
# imdb_score         1.757632
# imdb_votes        11.470860
# tmdb_popularity    9.065680
# tmdb_score         2.590194

# %% [markdown]
# ### **4. Inconsistent Values (Nilai tak konsisten)**

# %%
print("Nilai atau isi yang unik dari tiap kolom pada dataset:")
for col in df.columns:
    print(f'{col}= ', df[col].unique())
# Out:
# Nilai atau isi yang unik dari tiap kolom pada dataset:
# id=  ['ts21930' 'ts25177' 'ts35087' ... 'ts268254' 'ts285889' 'ts255190']
# title=  ['Lupin the Third' 'Mobile Suit Gundam' 'Galaxy Express 999' ...
#  'ABCiee Working Diary' 'GLOOMY The Naughty Grizzly' 'Idolls!']
# type=  ['SHOW' 'MOVIE']
# description=  ['Arsene Lupin III is the grandson of the master thief Arsene Lupin. With his cohorts Daisuke Jigen and Goemon Ishikawa XIII and his love interest Fujiko Mine, he pulls off the greatest heists of all time while always escaping the grasp of Inspector Koichi Zenigata.'
# ...

# %% [markdown]
# bisa dilihat tidak ada data yang tidak konsisten dengan kata lain data diatas semuanya konsisten.

# %% [markdown]
# ### **5. Penanganan data**

# %% [markdown]
# **Missing Values**

# %%
df['description'].fillna("No description available", inplace=True)
df['age_certification'].fillna(df['age_certification'].mode()[0], inplace=True)
df['seasons'].fillna(df['seasons'].median(), inplace=True)
df['imdb_score'].fillna(df['imdb_score'].median(), inplace=True)
df['imdb_votes'].fillna(df['imdb_votes'].median(), inplace=True)
df['tmdb_popularity'].fillna(df['tmdb_popularity'].median(), inplace=True)
df['tmdb_score'].fillna(df['tmdb_score'].median(), inplace=True)
df['imdb_id'].fillna("Unknown", inplace=True)
# Out:
# <ipython-input-14-1f4f40a2bc84>:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['description'].fillna("No description available", inplace=True)
# <ipython-input-14-1f4f40a2bc84>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# ...

# %%
print((df.isna().sum() / len(df)) * 100)
# Out:
# id                      0.0
# title                   0.0
# type                    0.0
# description             0.0
# release_year            0.0
# age_certification       0.0
# runtime                 0.0
# genres                  0.0
# production_countries    0.0
# seasons                 0.0
# imdb_id                 0.0
# imdb_score              0.0
# imdb_votes              0.0
# tmdb_popularity         0.0
# tmdb_score              0.0
# dtype: float64

# %% [markdown]
# data yang hilang sudah tidak ada

# %% [markdown]
# **Outliers**

# %%
columns_to_impute = ["release_year", "runtime", "seasons", "imdb_score", "imdb_votes", "tmdb_popularity", "tmdb_score"]

for col in columns_to_impute:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# Out:
# <ipython-input-16-9f78eb9a5beb>:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[2000.5 2000.5 2000.5 ... 2021.  2021.  2021. ]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)
# <ipython-input-16-9f78eb9a5beb>:10: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise in a future error of pandas. Value '[23.  25.  24.  ... 21.5 21.5 21.5]' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   df.loc[:, col] = df[col].clip(lower=lower_bound, upper=upper_bound)

# %%
results = []

cols = df.select_dtypes(include=['float64', 'int64'])

for col in cols:
  q1 = df[col].quantile(0.25)
  q3 = df[col].quantile(0.75)
  iqr = q3 - q1
  lower_bound = q1 - 1.5*iqr
  upper_bound = q3 + 1.5*iqr
  outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
  percent_outliers = (len(outliers)/len(df))*100
  results.append({'Kolom': col, '% Outliers': percent_outliers})

results_df = pd.DataFrame(results)
results_df.set_index('Kolom', inplace=True)
results_df = results_df.rename_axis(None, axis=0).rename_axis('Kolom', axis=1)

display(results_df)
# Out:
# Kolom            % Outliers
# release_year            0.0
# runtime                 0.0
# seasons                 0.0
# imdb_score              0.0
# imdb_votes              0.0
# tmdb_popularity         0.0
# tmdb_score              0.0

# %% [markdown]
# Sudah tidak ada Outliers

# %% [markdown]
# ### **6. konstruksi data (Construct Data) (penambahan kolom**)

# %%
df["genre_count"] = df["genres"].str.count(",") + 1
df["imdb_rating_category"] = pd.cut(df["imdb_score"], bins=[0, 4, 6, 8, 10], labels=["Poor", "Average", "Good", "Excellent"])

print(df.head())
# Out:
#         id                      title  type  \
# 0  ts21930            Lupin the Third  SHOW
# 1  ts25177         Mobile Suit Gundam  SHOW
# 2  ts35087         Galaxy Express 999  SHOW
# 3  ts82387              Lupin the 3rd  SHOW
# 4   ts2846  Chōdenji Machine Voltes V  SHOW
#
#                                          description  release_year  \
# 0  Arsene Lupin III is the grandson of the master...        2000.5
# 1  Mobile Suit Gundam is a televised anime series...        2000.5
# 2  Galaxy Express 999 is a manga written and draw...        2000.5
# 3  The master thief Lupin III and his cronies con...        2000.5
# 4  Chōdenji Machine Voltes V is a Japanese anime ...        2000.5
#
#   age_certification  runtime  \
# 0             TV-14     23.0
# 1             TV-Y7     25.0
# 2             TV-PG     24.0
# 3             TV-14     24.0
# 4             TV-PG     24.0
#
#                                               genres production_countries  \
# ...

# %% [markdown]
# Data yang ditambahkan ada 2 yaitu
#
#
# 1. genre count
#
# genre count untuk menghitung ada berapa banyak genre yang ada di dalam animenya
#
#
# 2. imdb rating category
#
# imdb rating category berfungsi untuk memberikan kelompok kategori seperti jika ratingnya 1 maka akan diberikan bad rating 2 good dst.

# %% [markdown]
# ### **7. Reduksi Data (Data Reduction)**

# %%
df = df.drop(columns=['production_countries'])
df.head()
# Out:
#         id                      title  type  \
# 0  ts21930            Lupin the Third  SHOW
# 1  ts25177         Mobile Suit Gundam  SHOW
# 2  ts35087         Galaxy Express 999  SHOW
# 3  ts82387              Lupin the 3rd  SHOW
# 4   ts2846  Chōdenji Machine Voltes V  SHOW
#
#                                          description  release_year  \
# 0  Arsene Lupin III is the grandson of the master...        2000.5
# 1  Mobile Suit Gundam is a televised anime series...        2000.5
# 2  Galaxy Express 999 is a manga written and draw...        2000.5
# 3  The master thief Lupin III and his cronies con...        2000.5
# 4  Chōdenji Machine Voltes V is a Japanese anime ...        2000.5
#
#   age_certification  runtime  \
# 0             TV-14     23.0
# 1             TV-Y7     25.0
# 2             TV-PG     24.0
# 3             TV-14     24.0
# 4             TV-PG     24.0
#
#                                               genres  seasons    imdb_id  \
# ...

# %% [markdown]
# # **CHECKPOINT 3**

# %% [markdown]
# ## **Jumlah Judul Per Tahun**

# %%
anime_per_year = df.groupby('release_year').size()
plt.figure(figsize=(10, 5))
sns.lineplot(x=anime_per_year.index, y=anime_per_year.values, marker='o', color='blue')
plt.title('Tren Jumlah Anime Per Tahun', fontsize=14)
plt.xlabel('Tahun Rilis', fontsize=12)
plt.ylabel('Jumlah Anime', fontsize=12)
plt.grid()
plt.show()

# %% [markdown]
# **INSIGHT**
#
# Grafik menunjukkan bahwa jumlah judul anime yang dirilis meningkat drastis sejak tahun 2000-an, dengan puncaknya sekitar tahun 2018-2020. Beberapa faktor yang mungkin memengaruhi peningkatan ini:
#
#
#
# 1. **Popularitas Global** - Anime semakin diterima secara internasional berkat platform streaming seperti Netflix dan Crunchyroll.
#
#
# 2. **Kemajuan Teknologi** - Produksi anime menjadi lebih efisien dengan teknologi digital dibandingkan animasi manual.
#
#
# 3. **Permintaan Pasar** - Bertambahnya penggemar anime mendorong studio untuk memproduksi lebih banyak konten.
#
#
# Namun, terlihat penurunan setelah 2020, yang kemungkinan disebabkan oleh pandemi COVID-19 yang menghambat produksi.

# %% [markdown]
# ## **IMDB Score vs TMDB Score**

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(data=df, x='imdb_score', y='tmdb_score', color='blue', alpha=0.5)
plt.title("Hubungan IMDb Score vs TMDb Score")
plt.xlabel("IMDb Score")
plt.ylabel("TMDb Score")
plt.grid()
plt.show()

# %% [markdown]
# ### **Korelasi**

# %%
df['imdb_score'] = pd.to_numeric(df['imdb_score'], errors='coerce')
df['tmdb_score'] = pd.to_numeric(df['tmdb_score'], errors='coerce')
correlation = df[['imdb_score', 'tmdb_score']].corr(method='pearson')
print(correlation)
# Out:
#             imdb_score  tmdb_score
# imdb_score    1.000000    0.437488
# tmdb_score    0.437488    1.000000

# %% [markdown]
# **INSIGHT**
#
#
# Dari scatter plot, terlihat bahwa skor IMDb dan TMDb memiliki korelasi sebesar **0.44**, yang menunjukkan **hubungan positif lemah hingga sedang**. Artinya:
#
# * **Skor di IMDb dan TMDb cenderung sejalan**, tetapi tidak sepenuhnya identik.
#
#
# * **Variasi skor menunjukkan perbedaan preferensi pengguna**, di mana salah satu platform mungkin lebih kritis dalam menilai.
#
#
# * **Sebaran data menunjukkan adanya outlier**, di mana beberapa film mendapat skor tinggi di satu platform tetapi lebih rendah di platform lainnya.
#
#
#
# Secara keseluruhan, meskipun ada hubungan antara IMDb dan TMDb score, **penilaian di kedua platform memiliki perbedaan yang cukup signifikan**.

# %% [markdown]
# ## **TOP 10 ANIME**

# %% [markdown]
# ### **Rata-Rata Skor IMDB dan TMDB**

# %%
df['average_score'] = df[['imdb_score', 'tmdb_score']].mean(axis=1)
top_10_anime = df.nlargest(10, 'average_score')[['title', 'average_score']]
print("Berikut adalah TOP 10 Anime berdasarkan rata-rata skor imdb dan tmdb:")
print(top_10_anime)
# Out:
# Berikut adalah TOP 10 Anime berdasarkan rata-rata skor imdb dan tmdb:
#                               title  average_score
# 947            Healin' Good♡Precure          8.850
# 279            Folktales from Japan          8.750
# 687                   Homicide City          8.750
# 32                        One Piece          8.725
# 243                 Hunter x Hunter          8.725
# 317                        Haikyu!!          8.725
# 815  Demon Slayer: Kimetsu no Yaiba          8.725
# 965                    SPY x FAMILY          8.725
# 319               Your Lie in April          8.700
# 42                  Fighting Spirit          8.675

# %% [markdown]
# ### **Visualisasi TOP 10 Anime Menggunakan Bar Chart**

# %%
plt.figure(figsize=(8, 5))
df.groupby('title')['average_score'].mean().nlargest(10).plot(kind='bar', color='skyblue')
plt.title('Top 10 Anime Berdasarkan Rata-rata IMDb & TMDb Score')
plt.xlabel('Judul Anime')
plt.ylabel('Rata-rata Skor')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# **INSIGHT**
#
# Dari bar chart **Top 10 Anime Berdasarkan Rata-rata IMDb & TMDb Score**, terlihat bahwa anime dengan skor tertinggi memiliki apresiasi tinggi di kedua platform. Artinya:
#
#
# - **Kualitas yang Konsisten:** Anime dengan skor tinggi cenderung memiliki cerita yang kuat, animasi berkualitas, dan karakter yang menarik.
#
#
# - **Penilaisan Pengguna:** Jika skor IMDb dan TMDb tidak jauh berbeda, berarti pengguna di kedua platform memiliki pandangan yang serupa mengenai anime tersebut.
#
#
# - **Genre dan Studio:** Anime dengan skor tinggi mungkin didominasi oleh genre tertentu seperti drama, psychological, atau action, serta diproduksi oleh studio terkenal yang sering menghasilkan karya berkualitas.
#
#
# - **Popularitas vs. Kualitas:** Tidak semua anime populer masuk dalam daftar ini, menunjukkan bahwa banyak penggemar tidak selalu berbanding lurus dengan kualitas tinggi.
#
#
#
# Secara keseluruhan, anime dengan skor IMDb dan TMDb tinggi cenderung memiliki kualitas yang diakui secara luas, baik dari segi cerita, animasi, maupun eksekusi keseluruhan.

# %% [markdown]
# ### **TINDAKAN YANG DAPAT DILAKUKAN**

# %% [markdown]
# 1. **Fokus pada Genre Populer**
#
#
# nominasi **TOP 10 Anime** tak luput dari yang namanya genre, genre genre yang populer diantaranya adalah Action, Adventure, dan Fantas
#
#
# **Tindakan**:
# * Menyediakan lebih banyak katalog anime dalam genre terpopuler yang memiliki jumlah judul tinggi, seperti Action, Adventure, dan Fantasy, karena genre ini memiliki permintaan tinggi.
#
#
#
# ---
#
#
# 2. **Lisensi Anime dengan Rating IMDb dan TMDb Tertinggi**
#
#
# Dari visualisasi IMDb vs TMDb di Checkpoint 3, kita melihat korelasi positif antara kedua skor.
#
#
#  **Tindakan**:
# * Lisensikan anime dengan rating tinggi di kedua platform karena anime dengan rating tinggi di satu platform cenderung juga memiliki rating tinggi di platform lainnya, sehingga lebih banyak menarik pelanggan.
#
#
# ---
#
#
#
# 3. **Adaptasi terhadap Tren Produksi Anime**
#
#
# Tiap tahun jumlah anime semakin meningkat, sebagai pemilik layanan streaming, sebaiknya harus update terhadap anime anime apa saja yang akan keluar.
#
#
#  **Tindakan**:
# * Pastikan platform memiliki akses ke rilisan terbaru dengan model simulcast (tayangan bersamaan dengan Jepang).
# * Berinvestasi dalam judul original atau eksklusif untuk mengikuti tren peningkatan jumlah anime.
#
#
# ---
#
#
#
# 4. **Kustomisasi Rekomendasi Berdasarkan Data Tren dan Skor IMDb/TMDb**
#
#
# Penonton pastinya akan memilih untuk menonton anime anime yang sedang populer, pastikan algoritma disesuaikan dengan trend dan selera pengguna.
#
#
# **Tindakan**:
# * Menggunakan AI rekomendasi berdasarkan rating, genre favorit user, dan tren produksi per tahun.
# * Memprioritaskan anime dengan korelasi tinggi antara IMDb dan TMDb untuk direkomendasikan kepada pengguna.
#
#
#
# ---
#
#
# 5. **Pengalaman Pengguna dan Aksesibilitas**
#
#
# pengalaman pengguna terhadap software juga penting, sediakan hal hal yang membuat pengguna semakin nyaman untuk menggunakan software.
#
#
# **Tindakan**:
# * Menyediakan multi-subtitle dan dubbing untuk meningkatkan aksesibilitas.
# * Meningkatkan UX/UI platform streaming, agar pengguna mudah menavigasi katalog besar yang terus bertambah.
